# %%
# Anatomy of an extension
# Out:
# # Anatomy of an extension

# %%
What an extension needs / Walking through key elements / Folder structure
# Out:
# What an extension needs / Walking through key elements / Folder structure

# %%
## Select the extension you like the most.
# Out:
# ## Select the extension you like the most.

# %%
    λ.YouTubeVideo()("EX_voquHdk0")
# Out:
#     λ.YouTubeVideo()("EX_voquHdk0")

# %%
    λ.YouTubeVideo()("PT9UIvLWUI0")
# Out:
#     λ.YouTubeVideo()("PT9UIvLWUI0")

# %%
Basic extension videos
5-10 minutes
# Out:
# Basic extension videos
# 5-10 minutes

# %%
Example(s)

make the basic thing.

Looking at cookie cutter is weird

Can we make a template from a cookie cutter


Alex how to write basic extensions

# %%
Front end extension/server extension
# Out:
# Front end extension/server extension

# %%
## Live debugging in watch mode video. (10mins)

### Gonzalo

### Martha`

## API docs
# Out:
# ## Live debugging in watch mode video. (10mins)
#
# ### Gonzalo
#
# ### Martha`
#
# ## API docs

# %%
Add these repos as submodules so their source can be seen in binder and the repo.

* https://github.com/jupyterlab/extension-cookiecutter-ts
* https://github.com/jupyterlab/extension-examples
# Out:
# Add these repos as submodules so their source can be seen in binder and the repo.
#
# * https://github.com/jupyterlab/extension-cookiecutter-ts
# * https://github.com/jupyterlab/extension-examples
